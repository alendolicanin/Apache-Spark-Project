# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# Inicijalizacija Spark sesije
# (Ovdje se stvara SparkSession objekat, koji je početna tačka za rad s podacima u Sparku. 
# appName se koristi za davanje imena aplikaciji Spark sesije.)
spark = SparkSession.builder.appName("PotrosnjaProizvoda").getOrCreate()

# Učitavanje podataka iz CSV fajla kao RDD
# (Linija koda čita tekstualnu datoteku "kupovina.csv" kao RDD linija. Svaka linija iz datoteke postaje jedan element u RDD-u.)
lines = spark.sparkContext.textFile("kupovina.csv")

# Pretvaranje linija u tuple oblika (customer ID, cena proizvoda)
# (Ovdje se svaka linija razdvaja po zarezu (,) kako bi se dobili pojedinačni elementi, a zatim se stvara RDD parova u obliku 
# tuple-a koji sadrže "customer ID" i cenu proizvoda kao float vrijednost.)
pairs = lines.map(lambda line: line.split(",")).map(lambda x: (x[0], float(x[2])))

# Računanje ukupne potrošnje po potrošaču
# (Koristi se reduceByKey da bi se izračunala ukupna potrošnja za svakog potrošača. Ova operacija sabira sve vrijednosti 
# (cenu proizvoda) za istog potrošača.)
total_spent = pairs.reduceByKey(lambda x, y: x + y)

# Prikaz rezultata
# (Rezultat se prikazuje petljom koja prolazi kroz rezultujući RDD (total_spent). Metoda collect() se koristi za prikupljanje 
# rezultata sa različitih čvorova klastera i vraćanje u Python proces gdje se mogu prikazati rezultati.)
for customer, total in total_spent.collect():
    print(f"Potrošač {customer} je potrošio ukupno {total} dinara.")

# Zaustavljanje Spark sesije
# (Ova linija završava Spark sesiju i oslobađa resurse nakon završetka obrade.)
spark.stop()
# Out:
# Potrošač 44 je potrošio ukupno 4756.890000000001 dinara.
# Potrošač 29 je potrošio ukupno 5032.530000000001 dinara.
# Potrošač 91 je potrošio ukupno 4642.26 dinara.
# Potrošač 70 je potrošio ukupno 5368.249999999999 dinara.
# Potrošač 53 je potrošio ukupno 4945.300000000001 dinara.
# Potrošač 14 je potrošio ukupno 4735.030000000001 dinara.
# Potrošač 50 je potrošio ukupno 4517.2699999999995 dinara.
# Potrošač 20 je potrošio ukupno 4836.860000000001 dinara.
# Potrošač 48 je potrošio ukupno 4384.33 dinara.
# Potrošač 4 je potrošio ukupno 4815.050000000001 dinara.
# Potrošač 57 je potrošio ukupno 4628.4 dinara.
# Potrošač 12 je potrošio ukupno 4664.589999999999 dinara.
# Potrošač 22 je potrošio ukupno 5019.449999999999 dinara.
# Potrošač 54 je potrošio ukupno 6065.390000000001 dinara.
# Potrošač 0 je potrošio ukupno 5524.949999999999 dinara.
# Potrošač 88 je potrošio ukupno 4830.55 dinara.
# Potrošač 86 je potrošio ukupno 4908.810000000001 dinara.
# Potrošač 40 je potrošio ukupno 5186.429999999999 dinara.
# Potrošač 98 je potrošio ukupno 4297.259999999999 dinara.
# Potrošač 83 je potrošio ukupno 4635.8 dinara.
# Potrošač 26 je potrošio ukupno 5250.4 dinara.
# Potrošač 60 je potrošio ukupno 5040.709999999999 dinara.
# Potrošač 21 je potrošio ukupno 4707.41 dinara.
# Potrošač 69 je potrošio ukupno 5123.01 dinara.
# Potrošač 1 je potrošio ukupno 4958.600000000001 dinara.
# Potrošač 64 je potrošio ukupno 5288.689999999999 dinara.
# Potrošač 82 je potrošio ukupno 4812.49 dinara.
# Potrošač 34 je potrošio ukupno 5330.8 dinara.
# Potrošač 73 je potrošio ukupno 6206.200000000001 dinara.
# Potrošač 8 je potrošio ukupno 5517.24 dinara.
# Potrošač 19 je potrošio ukupno 5059.43 dinara.
# Potrošač 16 je potrošio ukupno 4979.06 dinara.
# Potrošač 9 je potrošio ukupno 5322.65 dinara.
# Potrošač 74 je potrošio ukupno 4647.130000000001 dinara.
# Potrošač 56 je potrošio ukupno 4701.02 dinara.
# Potrošač 68 je potrošio ukupno 6375.450000000001 dinara.
# Potrošač 10 je potrošio ukupno 4819.7 dinara.
# Potrošač 17 je potrošio ukupno 5032.68 dinara.
# Potrošač 33 je potrošio ukupno 5254.660000000002 dinara.
# Potrošač 66 je potrošio ukupno 4681.92 dinara.
# Potrošač 77 je potrošio ukupno 4327.73 dinara.
# Potrošač 84 je potrošio ukupno 4652.9400000000005 dinara.
# Potrošač 93 je potrošio ukupno 5265.75 dinara.
# Potrošač 45 je potrošio ukupno 3309.3799999999997 dinara.
# Potrošač 24 je potrošio ukupno 5259.92 dinara.
# Potrošač 96 je potrošio ukupno 3924.2300000000005 dinara.
# Potrošač 63 je potrošio ukupno 5415.1500000000015 dinara.
# Potrošač 35 je potrošio ukupno 5155.420000000001 dinara.
# Potrošač 2 je potrošio ukupno 5994.59 dinara.
# Potrošač 47 je potrošio ukupno 4316.299999999998 dinara.
# Potrošač 85 je potrošio ukupno 5503.43 dinara.
# Potrošač 51 je potrošio ukupno 4975.220000000001 dinara.
# Potrošač 42 je potrošio ukupno 5696.840000000002 dinara.
# Potrošač 79 je potrošio ukupno 3790.5699999999997 dinara.
# Potrošač 15 je potrošio ukupno 5413.51 dinara.
# Potrošač 5 je potrošio ukupno 4561.07 dinara.
# Potrošač 31 je potrošio ukupno 4765.049999999999 dinara.
# Potrošač 36 je potrošio ukupno 4278.049999999999 dinara.
# Potrošač 13 je potrošio ukupno 4367.619999999999 dinara.
# Potrošač 55 je potrošio ukupno 5298.089999999999 dinara.
# Potrošač 95 je potrošio ukupno 4876.839999999998 dinara.
# Potrošač 61 je potrošio ukupno 5497.4800000000005 dinara.
# Potrošač 27 je potrošio ukupno 4915.89 dinara.
# Potrošač 78 je potrošio ukupno 4524.51 dinara.
# Potrošač 6 je potrošio ukupno 5397.879999999999 dinara.
# Potrošač 75 je potrošio ukupno 4178.5 dinara.
# Potrošač 25 je potrošio ukupno 5057.610000000001 dinara.
# Potrošač 71 je potrošio ukupno 5995.660000000002 dinara.
# Potrošač 39 je potrošio ukupno 6193.110000000001 dinara.
# Potrošač 97 je potrošio ukupno 5977.1900000000005 dinara.
# Potrošač 7 je potrošio ukupno 4755.069999999999 dinara.
# Potrošač 37 je potrošio ukupno 4735.200000000001 dinara.
# Potrošač 72 je potrošio ukupno 5337.439999999999 dinara.
# Potrošač 99 je potrošio ukupno 4172.29 dinara.
# Potrošač 49 je potrošio ukupno 4394.6 dinara.
# Potrošač 46 je potrošio ukupno 5963.109999999999 dinara.
# Potrošač 23 je potrošio ukupno 4042.65 dinara.
# Potrošač 65 je potrošio ukupno 5140.35 dinara.
# Potrošač 80 je potrošio ukupno 4727.86 dinara.
# Potrošač 18 je potrošio ukupno 4921.269999999999 dinara.
# Potrošač 59 je potrošio ukupno 5642.889999999999 dinara.
# Potrošač 30 je potrošio ukupno 4990.72 dinara.
# Potrošač 90 je potrošio ukupno 5290.41 dinara.
# Potrošač 11 je potrošio ukupno 5152.289999999999 dinara.
# Potrošač 41 je potrošio ukupno 5637.620000000001 dinara.
# Potrošač 58 je potrošio ukupno 5437.73 dinara.
# Potrošač 87 je potrošio ukupno 5206.4 dinara.
# Potrošač 62 je potrošio ukupno 5253.3200000000015 dinara.
# Potrošač 92 je potrošio ukupno 5379.279999999999 dinara.
# Potrošač 76 je potrošio ukupno 4904.210000000001 dinara.
# Potrošač 43 je potrošio ukupno 5368.83 dinara.
# Potrošač 52 je potrošio ukupno 5245.0599999999995 dinara.
# Potrošač 81 je potrošio ukupno 5112.709999999999 dinara.
# Potrošač 3 je potrošio ukupno 4659.63 dinara.
# Potrošač 89 je potrošio ukupno 4851.48 dinara.
# Potrošač 67 je potrošio ukupno 4505.79 dinara.
# Potrošač 94 je potrošio ukupno 4475.570000000001 dinara.
# Potrošač 32 je potrošio ukupno 5496.05 dinara.
# Potrošač 38 je potrošio ukupno 4898.460000000001 dinara.
# Potrošač 28 je potrošio ukupno 5000.709999999999 dinara.
